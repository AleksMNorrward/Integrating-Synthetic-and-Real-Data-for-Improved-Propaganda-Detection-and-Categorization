# %%
# !pip install kaggle

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-7daee05c-998f-4d4c-9499-b66c2a7cef58" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7daee05c-998f-4d4c-9499-b66c2a7cef58">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !ls -lha kaggle.json
# Out:
# -rw-r--r-- 1 root root 70 Apr 27 16:47 kaggle.json

# %%
# !pip install -q kaggle

# %%
# !mkdir -p ~/.kaggle #Create the directory
# !cp kaggle.json ~/.kaggle/

# %%
# !chmod 600 /root/.kaggle/kaggle.json

# %%
# !pwd
# Out:
# /content

# %%
# !kaggle datasets list
# Out:
# ...
# ref                                                              title                                                size  lastUpdated          downloadCount  voteCount  usabilityRating
# ---------------------------------------------------------------  --------------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# rahulvyasm/netflix-movies-and-tv-shows                           Netflix Movies and TV Shows                           1MB  2024-04-10 09:48:38           6934        138  1.0
# sujithmandala/second-hand-car-price-prediction                   Second Hand Car Price Prediction                      2KB  2024-04-24 12:09:30            880         24  1.0
# aniketmahajan1104/indian-cities-electricity-consumption-2017-19  Indian Cities Electricity Consumption 2017-19         2KB  2024-04-24 09:34:25            569         23  1.0
# ...

# %%
# !kaggle datasets download -d bohdanmynzar/twitter-propaganda-classification
# Out:
# ...
#   0% 0.00/2.24M [00:00<?, ?B/s]
# 100% 2.24M/2.24M [00:00<00:00, 125MB/s]

# %%
# !unzip twitter-propaganda-classification.zip
# Out:
# Archive:  twitter-propaganda-classification.zip
#   inflating: twitter_dataset.csv
#   inflating: twitter_dataset_translated_ukrainian.csv

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display, Markdown

# %%
data = pd.read_csv("/content/twitter_dataset.csv")
data.head()
# Out:
#    Unnamed: 0                   id                 created_at  \
# 0        1749  1514553915580329988  2022-04-14 10:39:27+00:00
# 1        2409  1510803460320632839  2022-04-04 02:16:28+00:00
# 2        2463  1475560113536741379  2021-12-27 20:12:00+00:00
# 3         116  1527722359314075649  2022-05-20 18:46:08+00:00
# 4        2742  1517110124325879808  2022-04-21 11:56:54+00:00
#
#                                                 text  is_propaganda
# 0  Woman who held up poster of Marine Le Pen and ...          False
# 1  ⚡️Zelensky: Around 150,000 people trapped in M...          False
# 2  RT @natomission_ru: 🇷🇺#Russia Deputy FM Sergey...           True
# 3  #Azovstal fully liberated – Russian military\n...           True
# 4  RT @BloombergUK: "He was almost foaming at the...          False

# %%
print('\n\033[1mInference: \033[0m', "The Dataset has ", data.shape[1], " attributes and ", data.shape[0], " samples")
print("\n\033[1mDataset Descriptive Statistics:\033[0m")
display(data.describe())
print("\n\033[1mCount of Non-NA Samples:\033[0m")
display(data.count())
print("\n\033[1mSum of NA samples in Features:\033[0m")
display(data.isna().sum())
print("\n\033[1mFeatures Initial Datatypes:\033[0m")
display(data.dtypes)
# Out:
# Inference:  The Dataset has  5  attributes and  12990  samples
#
# Dataset Descriptive Statistics:
#          Unnamed: 0            id
# count  12990.000000  1.299000e+04
# mean    1628.473595  1.512204e+18
# std      938.155215  1.536986e+16
# min        0.000000  1.459969e+18
# 25%      815.000000  1.508852e+18
# 50%     1630.000000  1.516647e+18
# 75%     2443.000000  1.522522e+18
# max     3248.000000  1.528501e+18
# Count of Non-NA Samples:
# Unnamed: 0       12990
# id               12990
# created_at       12990
# text             12990
# is_propaganda    12990
# dtype: int64
# Sum of NA samples in Features:
# Unnamed: 0       0
# id               0
# created_at       0
# text             0
# is_propaganda    0
# dtype: int64
# Features Initial Datatypes:
# Unnamed: 0        int64
# id                int64
# created_at       object
# text             object
# is_propaganda      bool
# dtype: object

# %%
display(Markdown("**Full Dataset:**"))
#data = pd.read_csv('/kaggle/input/twitter-propaganda-classification/twitter_dataset.csv')
display(data.head())
display("Full Dataset Shape: ", data.shape)

display(Markdown("**Clean (Non-Propagandistic) Text Dataset:**"))
clean_data = data[data['is_propaganda'] == False]
clean_data = clean_data[['text']]
display(clean_data.head())
display("Clean Text Dataset Shape: ",clean_data.shape)

display(Markdown("**Human Propaganda Dataset:**"))
df = data[data['is_propaganda'] == True]
df = df[['text']]
display(df.head())
display("Human Propaganda Text Dataset Shape: ",df.shape)
# Out:
# **Full Dataset:**
#    Unnamed: 0                   id                 created_at  \
# 0        1749  1514553915580329988  2022-04-14 10:39:27+00:00
# 1        2409  1510803460320632839  2022-04-04 02:16:28+00:00
# 2        2463  1475560113536741379  2021-12-27 20:12:00+00:00
# 3         116  1527722359314075649  2022-05-20 18:46:08+00:00
# 4        2742  1517110124325879808  2022-04-21 11:56:54+00:00
#
#                                                 text  is_propaganda
# 0  Woman who held up poster of Marine Le Pen and ...          False
# 1  ⚡️Zelensky: Around 150,000 people trapped in M...          False
# 2  RT @natomission_ru: 🇷🇺#Russia Deputy FM Sergey...           True
# 3  #Azovstal fully liberated – Russian military\n...           True
# 4  RT @BloombergUK: "He was almost foaming at the...          False
# 'Full Dataset Shape: '
# (12990, 5)
# **Clean (Non-Propagandistic) Text Dataset:**
#                                                  text
# ...

# %%
# !pip install openai
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.6/311.6 kB 3.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 4.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 6.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 4.0 MB/s eta 0:00:00
# ...

# %%
# !pip install openai==0.28

# %%
import openai

# %%
openai.api_key = 'api_key'

# %%
def generate_gpt3_response(user_text, print_output=False):
    """
    Query OpenAI GPT-3 for the specific key and get back a response
    :type user_text: str the user's text to query for
    :type print_output: boolean whether or not to print the raw output JSON
    """
    completions = ai.Completion.create(
        engine='text-davinci-003',  # Determines the quality, speed, and cost.
        temperature=0.5,            # Level of creativity in the response
        prompt=user_text,           # What the user typed in
        max_tokens=100,             # Maximum tokens in the prompt AND response
        n=1,                        # The number of completions to generate
        stop=None,                  # An optional setting to control response generation
    )

    # Displaying the output can be helpful if things go wrong
    if print_output:
        print(completions)

    # Return the first choice's text
    return completions.choices[0].text

# %%
# !pip install transformers

# %%
import transformers
from transformers import GPT2LMHeadModel, GPT2Tokenizer


# Load the GPT-2 model
model_name = "gpt2"
model = GPT2LMHeadModel.from_pretrained(model_name)
tokenizer = GPT2Tokenizer.from_pretrained(model_name)


# Get the course name and grade level
course_name = "Math"
grade_level = "3"
num_questions = 10
topics = "addition, subtraction, multiplication, and division"
prompt = f"Write an assignment for the course {course_name} for grade level {grade_level}. The assignment should be {num_questions} questions long and should cover the following topics: {topics}."


# tokenize the prompt
input_ids = tokenizer.encode(prompt, return_tensors="pt")


# generate the assignments
assignments = model.generate(
    input_ids,
    attention_mask=input_ids,
    pad_token_id=tokenizer.eos_token_id,
    max_length=512,
    num_return_sequences=1,
    temperature=0.7,
    top_k=5,
)



# decode and Print the assignment
for assignment in assignments:
    assignment = tokenizer.decode(assignment, skip_special_tokens=True)
    print(assignment, end="\n")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# ...

# %%
import torch
from transformers import GPT2LMHeadModel, GPT2Tokenizer

# Load the GPT-2 model
model_name = "gpt2"
model = GPT2LMHeadModel.from_pretrained(model_name)
tokenizer = GPT2Tokenizer.from_pretrained(model_name)

# Get the course name and grade level
course_name = "Math"
grade_level = "3"
num_questions = 10
topics = "addition, subtraction, multiplication, and division"
prompt = f"Write an assignment for the course {course_name} for grade level {grade_level}. The assignment should be {num_questions} questions long and should cover the following topics: {topics}."

# Tokenize the prompt
input_ids = tokenizer.encode(prompt, return_tensors="pt")

# Generate the assignments
assignments = model.generate(
    input_ids,
    max_length=512,
    num_return_sequences=1,
    temperature=0.7,
    do_sample=True,  # Set do_sample to True for sample-based generation
    top_k=50,  # Increased top_k value for more diverse sampling
    pad_token_id=tokenizer.eos_token_id,
    eos_token_id=tokenizer.eos_token_id,
    early_stopping=True
)

# Decode and print the assignment
for assignment in assignments:
    assignment = tokenizer.decode(assignment, skip_special_tokens=True)
    print(assignment, end="\n")
# Out:
# Write an assignment for the course Math for grade level 3. The assignment should be 10 questions long and should cover the following topics: addition, subtraction, multiplication, and division. As with any class, students should be able to ask questions that are not part of the assignment. This is especially important when assignments are taught in classes where students are not always familiar with the topics. Students should be able to understand the concepts. Note: The assignment will be given in all subjects, regardless of your grade level. The subject assignments are written in the order in which they were given. There may be multiple assignments. See the Class Schedule for more information.
#
# Sophomore Grade Level 4-6:
#
# 2.5 Questions on Math
#
# 3.5 Questions on Math
#
# 3.5 Questions on Math
#
# 4.5 Questions on Math
#
# 5.5 Questions on Math
#
# 5.5 Questions on Math
#
# 5.5 Questions on Math
#
# 5.5 Questions on Math
#
# 1.5 Questions on Math
#
# 2.5 Questions on Math
# ...

# %%
import pandas as pd
from transformers import GPT2LMHeadModel, GPT2Tokenizer, TextDataset, DataCollatorForLanguageModeling
from transformers import Trainer, TrainingArguments

# Load your text message dataset into a pandas DataFrame
# Replace 'your_dataset.csv' with the path to your dataset file
#df = pd.read_csv('your_dataset.csv')

# Initialize the GPT-2 tokenizer and model
tokenizer = GPT2Tokenizer.from_pretrained("gpt2")
model = GPT2LMHeadModel.from_pretrained("gpt2")

# Tokenize the text messages
text_messages = df['text'].tolist()
tokenized_messages = tokenizer(text_messages, return_tensors="pt", truncation=True, padding=True)

# Create a TextDataset using the tokenized messages
dataset = TextDataset(tokenized_messages)

# Define training arguments
training_args = TrainingArguments(
    per_device_train_batch_size=4,
    num_train_epochs=3,
    logging_dir='./logs',
    logging_steps=100,
    save_steps=1000,
    output_dir='./models',
    overwrite_output_dir=True,
    do_train=True
)

# Define a data collator for language modeling
data_collator = DataCollatorForLanguageModeling(tokenizer=tokenizer, mlm=False)

# Create a Trainer instance
trainer = Trainer(
    model=model,
    args=training_args,
    data_collator=data_collator,
    train_dataset=dataset
)

# Train the model
trainer.train()

# Generate messages similar to the input ones
generated_messages = []
for text_message in text_messages:
    input_ids = tokenizer.encode(text_message, return_tensors="pt")
    generated_message = model.generate(input_ids, max_length=100, num_return_sequences=1)
    generated_message = tokenizer.decode(generated_message[0], skip_special_tokens=True)
    generated_messages.append(generated_message)

# Create a DataFrame for the generated messages
generated_df = pd.DataFrame({'generated_message': generated_messages})

# Optionally, you can concatenate the generated messages with the original DataFrame
result_df = pd.concat([df, generated_df], axis=1)

# Save the result DataFrame to a CSV file
result_df.to_csv('result_dataset.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-befc2b0cb4bd> in <cell line: 15>()
#      13 # Tokenize the text messages
#      14 text_messages = df['text'].tolist()
# ---> 15 tokenized_messages = tokenizer(text_messages, return_tensors="pt", truncation=True, padding=True)
#      16
#      17 # Create a TextDataset using the tokenized messages
#
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py in __call__(self, text, text_pair, text_target, text_pair_target, add_special_tokens, padding, truncation, max_length, stride, is_split_into_words, pad_to_multiple_of, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, **kwargs)
#    2856             if not self._in_target_context_manager:
# ...

# %%
import pandas as pd
from transformers import GPT2LMHeadModel, GPT2Tokenizer, TextDataset, DataCollatorForLanguageModeling
from transformers import Trainer, TrainingArguments

# Load your text message dataset into a pandas DataFrame
# Replace 'your_dataset.csv' with the path to your dataset file
#df = pd.read_csv('your_dataset.csv')

# Initialize the GPT-2 tokenizer and model
tokenizer = GPT2Tokenizer.from_pretrained("gpt2")
model = GPT2LMHeadModel.from_pretrained("gpt2")

# Add a padding token to the tokenizer
tokenizer.add_special_tokens({'pad_token': '[PAD]'})

# Tokenize the text messages
text_messages = df['text'].tolist()
tokenized_messages = tokenizer(text_messages, return_tensors="pt", padding=True, truncation=True)

# Create a TextDataset using the tokenized messages
dataset = TextDataset(tokenized_messages)

# Define training arguments
training_args = TrainingArguments(
    per_device_train_batch_size=4,
    num_train_epochs=3,
    logging_dir='./logs',
    logging_steps=100,
    save_steps=1000,
    output_dir='./models',
    overwrite_output_dir=True,
    do_train=True
)

# Define a data collator for language modeling
data_collator = DataCollatorForLanguageModeling(tokenizer=tokenizer, mlm=False)

# Create a Trainer instance
trainer = Trainer(
    model=model,
    args=training_args,
    data_collator=data_collator,
    train_dataset=dataset
)

# Train the model
trainer.train()

# Generate messages similar to the input ones
generated_messages = []
for text_message in text_messages:
    input_ids = tokenizer.encode(text_message, return_tensors="pt", truncation=True)
    generated_message = model.generate(input_ids, max_length=100, num_return_sequences=1)
    generated_message = tokenizer.decode(generated_message[0], skip_special_tokens=True)
    generated_messages.append(generated_message)

# Create a DataFrame for the generated messages
generated_df = pd.DataFrame({'generated_message': generated_messages})
generated_df.head()
# Optionally, you can concatenate the generated messages with the original DataFrame
#result_df = pd.concat([df, generated_df], axis=1)

# Save the result DataFrame to a CSV file
#result_df.to_csv('result_dataset.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-90b3ce160774> in <cell line: 21>()
#      19
#      20 # Create a TextDataset using the tokenized messages
# ---> 21 dataset = TextDataset(tokenized_messages)
#      22
#      23 # Define training arguments
#
# TypeError: TextDataset.__init__() missing 2 required positional arguments: 'file_path' and 'block_size'

# %%
import pandas as pd
from transformers import GPT2LMHeadModel, GPT2Tokenizer, TextDataset, DataCollatorForLanguageModeling
from transformers import Trainer, TrainingArguments

# Load your text message dataset into a pandas DataFrame
# Replace 'your_dataset.csv' with the path to your dataset file
#df = pd.read_csv('your_dataset.csv')

# Initialize the GPT-2 tokenizer and model
tokenizer = GPT2Tokenizer.from_pretrained("gpt2")
model = GPT2LMHeadModel.from_pretrained("gpt2")

# Add a padding token to the tokenizer
tokenizer.add_special_tokens({'pad_token': '[PAD]'})

# Tokenize the text messages
text_messages = df['text'].tolist()
tokenized_messages = tokenizer(text_messages, return_tensors="pt", padding=True, truncation=True)

# Create a TextDataset from tokenized messages
dataset = TextDataset.from_tensors(tokenized_messages)

# Define training arguments
training_args = TrainingArguments(
    per_device_train_batch_size=4,
    num_train_epochs=3,
    logging_dir='./logs',
    logging_steps=100,
    save_steps=1000,
    output_dir='./models',
    overwrite_output_dir=True,
    do_train=True
)

# Define a data collator for language modeling
data_collator = DataCollatorForLanguageModeling(tokenizer=tokenizer, mlm=False)

# Create a Trainer instance
trainer = Trainer(
    model=model,
    args=training_args,
    data_collator=data_collator,
    train_dataset=dataset
)

# Train the model
trainer.train()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-a3002605c79b> in <cell line: 21>()
#      19
#      20 # Create a TextDataset from tokenized messages
# ---> 21 dataset = TextDataset.from_tensors(tokenized_messages)
#      22
#      23 # Define training arguments
#
# AttributeError: type object 'TextDataset' has no attribute 'from_tensors'

# %%
5!pip install accelerate -U

# %%
# !pip install transformers[torch]
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 297.6/297.6 kB 6.0 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# ...

# %%
# !pip install accelerate>=0.21.0

# %%
# !pip install -U accelerate
# !pip install -U transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 297.6/297.6 kB 5.9 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# ...

# %%
import pandas as pd
from transformers import GPT2LMHeadModel, GPT2Tokenizer, TextDataset, DataCollatorForLanguageModeling
from transformers import Trainer, TrainingArguments
from torch.utils.data import Dataset

# Load your text message dataset into a pandas DataFrame
# Replace 'your_dataset.csv' with the path to your dataset file
#df = pd.read_csv('your_dataset.csv')

# Initialize the GPT-2 tokenizer and model
tokenizer = GPT2Tokenizer.from_pretrained("gpt2")
model = GPT2LMHeadModel.from_pretrained("gpt2")

# Add a padding token to the tokenizer
tokenizer.add_special_tokens({'pad_token': '[PAD]'})

# Tokenize the text messages
text_messages = df['text'].tolist()
tokenized_messages = tokenizer(text_messages, return_tensors="pt", padding=True, truncation=True)

# Define a custom dataset class
class CustomDataset(Dataset):
    def __init__(self, tokenized_messages):
        self.input_ids = tokenized_messages["input_ids"]
        self.attention_mask = tokenized_messages["attention_mask"]

    def __len__(self):
        return len(self.input_ids)

    def __getitem__(self, idx):
        return {"input_ids": self.input_ids[idx], "attention_mask": self.attention_mask[idx]}

# Create a custom dataset from tokenized messages
dataset = CustomDataset(tokenized_messages)

# Define training arguments
training_args = TrainingArguments(
    per_device_train_batch_size=4,
    num_train_epochs=3,
    logging_dir='./logs',
    logging_steps=100,
    save_steps=1000,
    output_dir='./models',
    overwrite_output_dir=True,
    do_train=True
)

# Define a data collator for language modeling
data_collator = DataCollatorForLanguageModeling(tokenizer=tokenizer, mlm=False)

# Create a Trainer instance
trainer = Trainer(
    model=model,
    args=training_args,
    data_collator=data_collator,
    train_dataset=dataset
)

# Train the model
trainer.train()
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# ...

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"  # Use only GPU 0

# %%
os.environ['CUDA_LAUNCH_BLOCKING'] = '1'

# %% [markdown]
# **—————————————————**

# %%
# Initialize the GPT-3 model
model = "babbage-002"  # Choose the appropriate model

# %%
# Specify parameters for text generation
parameters = {
    "temperature": 0.7,  # Higher temperature leads to more creative output
    "max_tokens": 100,    # Control the length of each generated sample
    "top_p": 1.0         # Nucleus sampling parameter
}

# %%
# Generate text
generated_data = []
num_samples = 20000
batch_size = 10

# %%
# Concatenate text from DataFrame into a single string
input_dataset = '\n'.join(human_propaganda['text'])

# %%
while len(generated_data) < num_samples:
    response = openai.Completion.create(
        engine=model,
        prompt=input_dataset,
        max_tokens=50,  # Adjust the length of each generated sample as needed
        n=1,            # Generate 1 sample per request
        stop='\n',      # Stop generation at the end of each sample
        temperature=0.7 # Control the creativity of the generated text
    )
    generated_data.extend(response['choices'][0]['text'].strip().split('\n'))

# Save the generated dataset
with open('generated_dataset.txt', 'w') as f:
    f.write('\n'.join(generated_data))
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# <ipython-input-32-118a5f365db7> in <cell line: 1>()
#       1 while len(generated_data) < num_samples:
# ----> 2     response = openai.Completion.create(
#       3         engine=model,
#       4         prompt=input_dataset,
#       5         max_tokens=50,  # Adjust the length of each generated sample as needed
#
# /usr/local/lib/python3.10/dist-packages/openai/api_resources/completion.py in create(cls, *args, **kwargs)
#      23         while True:
#      24             try:
# ---> 25                 return super().create(*args, **kwargs)
#      26             except TryAgain as e:
#      27                 if timeout is not None and time.time() > start + timeout:
#
# ...

# %% [markdown]
# #**Data for ChatGPT3-5**

# %%
# !kaggle datasets download -d vladimirsydor/propaganda-detection-our-data
# Out:
# ...
#   0% 0.00/198k [00:00<?, ?B/s]
# 100% 198k/198k [00:00<00:00, 56.8MB/s]

# %%
# !unzip propaganda-detection-our-data.zip
# Out:
# Archive:  propaganda-detection-our-data.zip
#   inflating: fake_detection_df_test.csv
#   inflating: fake_detection_df_train.csv
#   inflating: fake_detection_df_val.csv

# %%
display(Markdown("**Full Dataset:**"))
data_train = pd.read_csv('/content/fake_detection_df_train.csv')
display(data_train.head())
display("Full Dataset Shape: ", data_train.shape)
# Out:
# **Full Dataset:**
#             id                                               text  label
# 0  00000_03514  Чернигов прилет во многоэтажку. Говорят русска...   True
# 1  00002_06059  Председатель Следственного комитета РФ Алексан...   True
# 2  00003_08645         Все сейчас массово хотят уехать со Львова.   True
# 3  00004_00901  «К военным подошли бабушки и попросили убрать ...   True
# 4  00006_06251  С уважение отношусь к Лобаеву, но Владислав, е...   True
# 'Full Dataset Shape: '
# (880, 3)

# %%
display(Markdown("**Clean (Non-Propagandistic) Text Dataset:**"))
clean_data_train = data_train[data_train['label'] == False]
clean_data_train = clean_data_train[['text']]
display(clean_data_train.head())
display("Clean Text Dataset Shape: ",clean_data_train.shape)

display(Markdown("**Human Propaganda Dataset:**"))
propaganda_train = data_train[data_train['label'] == True]
propaganda_train = propaganda_train[['text']]
display(propaganda_train.head())
display("Human Propaganda Text Dataset Shape: ",propaganda_train.shape)
# Out:
# **Clean (Non-Propagandistic) Text Dataset:**
#                                                  text
# 5   ⚠️ ? Зафиксирован обстрел со стороны ВФУ по на...
# 7                 Ми-35 ВКС России прикрывает колонну
# 8              ? Ещё видео со зданием СБУ в Чернигове
# 9   Блинкен в разговоре с Кулебой заявил, что США ...
# 10  ⚡️ Эдуарб Басурин: Подразделения ДНР взяли под...
# 'Clean Text Dataset Shape: '
# (336, 1)
# **Human Propaganda Dataset:**
#                                                 text
# 0  Чернигов прилет во многоэтажку. Говорят русска...
# 1  Председатель Следственного комитета РФ Алексан...
# 2         Все сейчас массово хотят уехать со Львова.
# 3  «К военным подошли бабушки и попросили убрать ...
# 4  С уважение отношусь к Лобаеву, но Владислав, е...
# 'Human Propaganda Text Dataset Shape: '
# (544, 1)

# %%
display(Markdown("**Full Dataset:**"))
data_test = pd.read_csv('/content/fake_detection_df_test.csv')
display(data_test.head())
display("Full Dataset Shape: ", data_test.shape)

display(Markdown("**Clean (Non-Propagandistic) Text Dataset:**"))
clean_data_test = data_test[data_test['label'] == False]
clean_data_test = clean_data_test[['text']]
display(clean_data_test.head())
display("Clean Text Dataset Shape: ",clean_data_test.shape)

display(Markdown("**Human Propaganda Dataset:**"))
human_propaganda_test = data_test[data_test['label'] == True]
human_propaganda_test = human_propaganda_test[['text']]
display(human_propaganda_test.head())
display("Human Propaganda Text Dataset Shape: ",human_propaganda_test.shape)
# Out:
# **Full Dataset:**
#             id                                               text  label
# 0  00780_04282  ⚡️ Борис Джонсон предлагает лидерам стран НАТО...  False
# 1  00784_05901  Зеленский сообщил о новых поставках оружия от ...  False
# 2  00786_05398  Бесстыдство — главная черта западных коллег, н...   True
# 3  00788_04827  ⚡️ Зеленский вновь предложил Владимиру Путину ...  False
# 4  00797_04856  И вдогонку — оказавшийся под санкциями ВТБ изб...  False
# 'Full Dataset Shape: '
# (248, 3)
# **Clean (Non-Propagandistic) Text Dataset:**
#                                                 text
# 0  ⚡️ Борис Джонсон предлагает лидерам стран НАТО...
# 1  Зеленский сообщил о новых поставках оружия от ...
# 3  ⚡️ Зеленский вновь предложил Владимиру Путину ...
# 4  И вдогонку — оказавшийся под санкциями ВТБ изб...
# 7  Подразделения ВСУ отошли с занимаемых позиций ...
# 'Clean Text Dataset Shape: '
# (109, 1)
# **Human Propaganda Dataset:**
# ...

# %%
display(Markdown("**Full Dataset:**"))
data_val = pd.read_csv('/content/fake_detection_df_val.csv')
display(data_val.head())
display("Full Dataset Shape: ", data_val.shape)

display(Markdown("**Clean (Non-Propagandistic) Text Dataset:**"))
clean_data_val = data_val[data_val['label'] == False]
clean_data_val = clean_data_val[['text']]
display(clean_data_val.head())
display("Clean Text Dataset Shape: ",clean_data_val.shape)

display(Markdown("**Human Propaganda Dataset:**"))
human_propaganda_val = data_val[data_val['label'] == True]
human_propaganda_val = human_propaganda_val[['text']]
display(human_propaganda_val.head())
display("Human Propaganda Text Dataset Shape: ",human_propaganda_val.shape)
# Out:
# **Full Dataset:**
#             id                                               text  label
# 0  00013_03711  Украинские ИПсО продолжают снимать блокбастеры...   True
# 1  00024_04965  «Финляндия готовится закрыть воздушное простра...  False
# 2  00030_08877  Корреспондент РИА Новости показывает последств...  False
# 3  00050_05750  Столтенберг верит, что война на Украине не рас...  False
# 4  00057_04788  ⚡️ Военнослужащие ЛНР без боя освободили два к...  False
# 'Full Dataset Shape: '
# (127, 3)
# **Clean (Non-Propagandistic) Text Dataset:**
#                                                 text
# 1  «Финляндия готовится закрыть воздушное простра...
# 2  Корреспондент РИА Новости показывает последств...
# 3  Столтенберг верит, что война на Украине не рас...
# 4  ⚡️ Военнослужащие ЛНР без боя освободили два к...
# 7                  ❗️ ?? ?? Над Херсоном истребитель
# 'Clean Text Dataset Shape: '
# (48, 1)
# **Human Propaganda Dataset:**
# ...

# %%
human_propaganda = pd.concat([propaganda_train, human_propaganda_test, human_propaganda_val], ignore_index=True)
display(human_propaganda.head())
display("Human Propaganda New Full Dataset Shape: ",human_propaganda.shape)
# Out:
#                                                 text
# 0  Чернигов прилет во многоэтажку. Говорят русска...
# 1  Председатель Следственного комитета РФ Алексан...
# 2         Все сейчас массово хотят уехать со Львова.
# 3  «К военным подошли бабушки и попросили убрать ...
# 4  С уважение отношусь к Лобаеву, но Владислав, е...
# 'Human Propaganda New Full Dataset Shape: '
# (762, 1)

# %%
pd.set_option('display.max_colwidth', None)

# %%
human_propaganda.head(100)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             text
# ...

# %%
human_propaganda.to_csv('Human Propaganda Dataset.csv', index=False)
